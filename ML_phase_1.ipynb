# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('BankChurners.csv')

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_2 = df[(df['Income_Category']!= 'Unknown') & (df['Customer_Age']!= 'Unknown') & (df['Education_Level']!= 'Unknown')]

# %%
df_2
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10121  713899383  Existing Customer            56      F                1
# 10122  772366833  Existing Customer            50      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
updated_df = df_2[['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category', 'Months_on_book', 'Credit_Limit', 'Avg_Utilization_Ratio']]

# %%
updated_df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10121  713899383  Existing Customer            56      F                1
# 10122  772366833  Existing Customer            50      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
updated_df_1 = updated_df.loc[1 : 5000]

# %%
updated_df_1
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1     818770008  Existing Customer            49      F                5
# 2     713982108  Existing Customer            51      M                3
# 3     769911858  Existing Customer            40      F                4
# 4     709106358  Existing Customer            40      M                3
# 5     713061558  Existing Customer            44      M                2
# ...         ...                ...           ...    ...              ...
# 4993  709679658  Existing Customer            58      F                2
# 4994  779296908  Existing Customer            46      F                3
# 4998  789775308  Existing Customer            54      F                2
# 4999  714726858  Attrited Customer            31      F                0
# 5000  709749483  Existing Customer            40      F                2
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
updated_df_1['Attrition_Flag'].value_counts()['Existing Customer']
# Out:
# 3414

# %%
updated_df_1['Attrition_Flag'].value_counts()['Attrited Customer']
# Out:
# 437

# %%
updated_df_1.shape
# Out:
# (3851, 12)

# %%
updated_df_1.size
# Out:
# 46212

# %%
updated_df_1.describe
# Out:
# <bound method NDFrame.describe of       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1     818770008  Existing Customer            49      F                5
# 2     713982108  Existing Customer            51      M                3
# 3     769911858  Existing Customer            40      F                4
# 4     709106358  Existing Customer            40      M                3
# 5     713061558  Existing Customer            44      M                2
# ...         ...                ...           ...    ...              ...
# 4993  709679658  Existing Customer            58      F                2
# 4994  779296908  Existing Customer            46      F                3
# 4998  789775308  Existing Customer            54      F                2
# 4999  714726858  Attrited Customer            31      F                0
# 5000  709749483  Existing Customer            40      F                2
#
# ...

# %%
updated_df_1.duplicated().sum()
# Out:
# 0

# %%
updated_df_1.nunique()
# Out:
# CLIENTNUM                3851
# Attrition_Flag              2
# Customer_Age               45
# Gender                      2
# Dependent_count             6
# Education_Level             6
# Marital_Status              4
# Income_Category             5
# Card_Category               4
# Months_on_book             44
# Credit_Limit             3014
# Avg_Utilization_Ratio     856
# dtype: int64

# %%
sns.pairplot(data=updated_df_1)

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.boxplot(df["Months_on_book"])
plt.subplot(2,2,2)
sns.boxplot(df["Dependent_count"])
plt.subplot(2,2,3)
sns.boxplot(df["Credit_Limit"])
plt.show()

# %%
plt.scatter(updated_df_1['Months_on_book'], updated_df_1['Avg_Utilization_Ratio'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(30,20))
plt.subplot(2,2,1)
sns.countplot(x = "Education_Level",hue="Income_Category",data=updated_df_1)
plt.subplot(2,2,2)
sns.countplot(x = "Customer_Age",hue="Attrition_Flag",data=updated_df_1)
plt.subplot(2,2,3)
sns.lineplot(x = "Customer_Age",y = "Dependent_count",data=updated_df_1)
plt.subplot(2,2,4)
sns.countplot(x = "Gender",hue="Income_Category",data=updated_df_1)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>
